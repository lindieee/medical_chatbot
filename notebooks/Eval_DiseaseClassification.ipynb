# %% [markdown]
# # Evaluation on Disease Classification

# %%
# https://www.youtube.com/watch?v=ac6ZB5QEwGU&ab_channel=DataTalksClub%E2%AC%9B
# https://huggingface.co/datasets/PardisSzah/DiseaseDecipher

# %%
import TestBot_for_Eval

# %%
import pandas as pd
from tqdm import tqdm
import random
from tqdm.asyncio import tqdm_asyncio
from sklearn.metrics import accuracy_score
from ollama import ChatResponse
import asyncio
import nest_asyncio

# %%
nest_asyncio.apply()

# %%
#query = "What is lung cancer"
#bot_response = TestBot_for_Eval.chatbot_response(query)
#bot_response

# %% [markdown]
# ## EDA Test dataset

# %%
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("documents/DiseaseDecipher.csv")

# %%
df.shape
# Out:
# (12736, 4)

# %%
df.columns
# Out:
# Index(['Question', 'Answer Disease', 'Answer Index', 'Number of Symptoms'], dtype='object')

# %%
df.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                  Question  \
# 12731  A patient is presenting with the following symptoms: Eye redness, Pain in eye, Itchiness of eye, Fever, Swollen eye, Nasal congestion. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Arrhythmia 2) Skin cancer 3) Lateral epicondylitis (tennis elbow) 4) Conjunctivitis due to virus
# 12732               A patient is presenting with the following symptoms: Headache, Nosebleed, Facial pain, Hot flashes, Sleepiness, Sore in nose. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Open wound of the nose 2) Bone cancer 3) Ganglion cyst 4) Paroxysmal ventricular tachycardia
# 12733               A patient is presenting with the following symptoms: Headache, Nosebleed, Facial pain, Hot flashes, Sleepiness, Sore in nose. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Paroxysmal ventricular tachycardia 2) Open wound of the nose 3) Bone cancer 4) Ganglion cyst
# 12734               A patient is presenting with the following symptoms: Headache, Nosebleed, Facial pain, Hot flashes, Sleepiness, Sore in nose. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Bone cancer 2) Paroxysmal ventricular tachycardia 3) Open wound of the nose 4) Ganglion cyst
# 12735               A patient is presenting with the following symptoms: Headache, Nosebleed, Facial pain, Hot flashes, Sleepiness, Sore in nose. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Bone cancer 2) Paroxysmal ventricular tachycardia 3) Ganglion cyst 4) Open wound of the nose
#
#                     Answer Disease  Answer Index  Number of Symptoms
# 12731  Conjunctivitis due to virus             4                   6
# 12732       Open wound of the nose             1                   6
# 12733       Open wound of the nose             2                   6
# 12734       Open wound of the nose             3                   6
# 12735       Open wound of the nose             4                   6

# %% [markdown]
# ## Dataset intersection

# %% [markdown]
# ### Idea: use only those diseases for testing which were in the database creation dataset, so QureAI should know about it

# %%
diseases = list(set(df["Answer Disease"].to_list()))

# %%
len(diseases)
# Out:
# 796

# %%
df_medquad = pd.read_csv("documents/medquad.csv")

# %%
df_medquad.columns
# Out:
# Index(['question', 'answer', 'source', 'focus_area'], dtype='object')

# %%
diseases_medquad = list(df_medquad.focus_area.unique())

# %%
len(diseases_medquad)
# Out:
# 5127

# %%
disease_intersection = [d for d in diseases if d in diseases_medquad]

# %%
len(disease_intersection)
# Out:
# 147

# %%
disease_intersection[0]
# Out:
# 'Down syndrome'

# %%
df.columns
# Out:
# Index(['Question', 'Answer Disease', 'Answer Index', 'Number of Symptoms'], dtype='object')

# %%
filtered_df = df[df['Answer Disease'].isin(disease_intersection)]

# %%
filtered_df = filtered_df.reset_index()

# %%
filtered_df.shape
# Out:
# (2352, 5)

# %%
filtered_df.head()
# Out:
#    index  \
# 0      8
# 1      9
# 2     10
# 3     11
# 4     72
#
#                                                                                                                                                                                                                                                                   Question  \
# 0        A patient is presenting with the following symptoms: Groin mass, Leg pain, Hip pain. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Turner syndrome 2) Ulcerative colitis 3) Eye alignment disorder 4) Hyperlipidemia
# 1        A patient is presenting with the following symptoms: Groin mass, Leg pain, Hip pain. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Hyperlipidemia 2) Turner syndrome 3) Eye alignment disorder 4) Ulcerative colitis
# 2        A patient is presenting with the following symptoms: Groin mass, Leg pain, Hip pain. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Eye alignment disorder 2) Ulcerative colitis 3) Turner syndrome 4) Hyperlipidemia
# 3        A patient is presenting with the following symptoms: Groin mass, Leg pain, Hip pain. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Eye alignment disorder 2) Hyperlipidemia 3) Ulcerative colitis 4) Turner syndrome
# 4  A patient is presenting with the following symptoms: Diminished vision, Pain in eye, Symptoms of eye. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Glaucoma 2) Herpangina 3) G6PD enzyme deficiency 4) Pulmonary embolism
#
#     Answer Disease  Answer Index  Number of Symptoms
# 0  Turner syndrome             1                   3
# 1  Turner syndrome             2                   3
# 2  Turner syndrome             3                   3
# 3  Turner syndrome             4                   3
# 4         Glaucoma             1                   3

# %%
filtered_df.to_csv('documents/filtered_test_data.csv', index=False)

# %% [markdown]
# ## Select random eval sample

# %%
sample_size = 100
random.seed(42)
sample_ids = random.sample(range(len(filtered_df)), sample_size)

# %%
sample_questions = [filtered_df.loc[i, "Question"] for i in sample_ids]
sample_answers = [filtered_df.loc[i, "Answer Disease"] for i in sample_ids]

# %%
sample_questions[:4]
# Out:
# ['A patient is presenting with the following symptoms: Fever, Cough, Sore throat. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Flu 2) Avascular necrosis 3) Mastectomy 4) Open wound of the lip',
#  'A patient is presenting with the following symptoms: Skin rash, Skin lesion, Headache. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Bone disorder 2) Injury to the leg 3) Vasculitis 4) Pneumothorax',
#  'A patient is presenting with the following symptoms: Eye redness, Diminished vision, Itchy scalp, Blindness. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Rosacea 2) Poisoning due to antihypertensives 3) Toxoplasmosis 4) High blood pressure',
#  'A patient is presenting with the following symptoms: Weakness, Fatigue, Chills, Problems with movement. Based on these symptoms, which of the following diseases is the most likely diagnosis?\n1) Open wound due to trauma 2) Conjunctivitis 3) Ascending cholangitis 4) Multiple myeloma']

# %% [raw]
# import json
# with open("documents/sample_ids_for_testing.json", "w") as f:
# 	json.dump(sample_ids, f)

# %%
len(sample_questions), len(sample_answers)
# Out:
# (100, 100)

# %% [markdown]
# ## Eval without RAG

# %%
# https://python.langchain.com/docs/integrations/chat/ollama/

# %%
import warnings
from langchain.prompts.prompt import PromptTemplate
from langchain_community.chat_models import ChatOllama
from langchain_core.runnables import RunnableConfig

# %%
# !ollama list
# Out:
# NAME              ID              SIZE      MODIFIED
# mistral:latest    3944fe81ec14    4.1 GB    5 days ago
# llama3.2:1b       baf6a787fdff    1.3 GB    5 days ago
# deepseek-r1:8b    6995872bfe4c    5.2 GB    5 days ago
# llama3:latest     365c0bd3c000    4.7 GB    5 days ago

# %%
#!ollama pull "mistral"
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  59 KB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 502 KB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 1.3 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 2.1 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 2.4 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 2.9 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 3.6 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 3.9 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 3.9 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 3.9 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 3.9 MB/4.1 GB                  pulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 4.4 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 4.4 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 4.4 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 4.7 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 5.3 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 5.3 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 5.4 MB/4.1 GB  4.1 MB/s  16m46spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 7.0 MB/4.1 GB  4.1 MB/s  16m45spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 7.7 MB/4.1 GB  4.1 MB/s  16m45spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 8.0 MB/4.1 GB  4.1 MB/s  16m45spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 8.0 MB/4.1 GB  4.0 MB/s  17m14spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 8.0 MB/4.1 GB  4.0 MB/s  17m14spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 8.8 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 9.0 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 9.0 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 9.1 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 9.8 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏ 9.8 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  10 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  10 MB/4.1 GB  4.0 MB/s  17m13spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  11 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  11 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  11 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  11 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  12 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  12 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  12 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  12 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  12 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  13 MB/4.1 GB  3.8 MB/s  17m59spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  13 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  13 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  13 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  14 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  14 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  14 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  14 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  15 MB/4.1 GB  3.4 MB/s  20m16spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  15 MB/4.1 GB  3.4 MB/s  20m15spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  15 MB/4.1 GB  3.4 MB/s  20m15spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  15 MB/4.1 GB  3.2 MB/s  21m32spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  16 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  16 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  16 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  16 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  17 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  17 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  18 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  18 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  18 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  19 MB/4.1 GB  3.2 MB/s  21m31spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  19 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  19 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  19 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  19 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  20 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  20 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  20 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   0% ▕                  ▏  20 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  20 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  20 MB/4.1 GB  3.2 MB/s  21m24spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  21 MB/4.1 GB  3.0 MB/s  22m49spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  21 MB/4.1 GB  3.0 MB/s  22m49spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  21 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  22 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  22 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  22 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  22 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  22 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  22 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  23 MB/4.1 GB  3.0 MB/s  22m48spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  23 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  23 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  23 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  24 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  24 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  24 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  24 MB/4.1 GB  3.0 MB/s   23m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  25 MB/4.1 GB  3.0 MB/s   23m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  25 MB/4.1 GB  3.0 MB/s   23m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  25 MB/4.1 GB  3.0 MB/s   23m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  26 MB/4.1 GB  2.9 MB/s  23m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  26 MB/4.1 GB  2.9 MB/s  23m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  26 MB/4.1 GB  2.9 MB/s  23m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  26 MB/4.1 GB  2.9 MB/s  23m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  26 MB/4.1 GB  2.9 MB/s  23m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  26 MB/4.1 GB  2.9 MB/s  23m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  27 MB/4.1 GB  2.9 MB/s  23m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  27 MB/4.1 GB  2.9 MB/s  23m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  27 MB/4.1 GB  2.9 MB/s  23m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  27 MB/4.1 GB  2.9 MB/s  23m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  28 MB/4.1 GB  2.7 MB/s  25m30spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  28 MB/4.1 GB  2.7 MB/s  25m30spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  28 MB/4.1 GB  2.7 MB/s  25m30spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  28 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  29 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  29 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  29 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  29 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  30 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  30 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  30 MB/4.1 GB  2.7 MB/s  25m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  31 MB/4.1 GB  2.6 MB/s  26m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  31 MB/4.1 GB  2.6 MB/s  26m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  31 MB/4.1 GB  2.6 MB/s  26m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  31 MB/4.1 GB  2.6 MB/s  26m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  32 MB/4.1 GB  2.6 MB/s  26m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  32 MB/4.1 GB  2.6 MB/s  26m27spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  32 MB/4.1 GB  2.6 MB/s  26m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  32 MB/4.1 GB  2.6 MB/s  26m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  33 MB/4.1 GB  2.6 MB/s  26m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  33 MB/4.1 GB  2.6 MB/s  26m26spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  34 MB/4.1 GB  2.5 MB/s   27m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  34 MB/4.1 GB  2.5 MB/s   27m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  34 MB/4.1 GB  2.5 MB/s   27m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  35 MB/4.1 GB  2.5 MB/s   27m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  35 MB/4.1 GB  2.5 MB/s   27m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  35 MB/4.1 GB  2.5 MB/s   27m1spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  35 MB/4.1 GB  2.5 MB/s   27m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  35 MB/4.1 GB  2.5 MB/s   27m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  36 MB/4.1 GB  2.5 MB/s   27m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  36 MB/4.1 GB  2.5 MB/s   27m0spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  37 MB/4.1 GB  2.6 MB/s  25m52spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  37 MB/4.1 GB  2.6 MB/s  25m52spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  37 MB/4.1 GB  2.6 MB/s  25m52spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  37 MB/4.1 GB  2.6 MB/s  25m52spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  38 MB/4.1 GB  2.6 MB/s  25m51spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  38 MB/4.1 GB  2.6 MB/s  25m51spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  38 MB/4.1 GB  2.6 MB/s  25m51spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  38 MB/4.1 GB  2.6 MB/s  25m51spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  38 MB/4.1 GB  2.6 MB/s  25m51spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  39 MB/4.1 GB  2.6 MB/s  25m51spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  39 MB/4.1 GB  2.7 MB/s  25m35spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  40 MB/4.1 GB  2.7 MB/s  25m35spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  40 MB/4.1 GB  2.7 MB/s  25m35spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  40 MB/4.1 GB  2.7 MB/s  25m35spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  41 MB/4.1 GB  2.7 MB/s  25m34spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  41 MB/4.1 GB  2.7 MB/s  25m34spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  42 MB/4.1 GB  2.7 MB/s  25m34spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  42 MB/4.1 GB  2.7 MB/s  25m34spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  42 MB/4.1 GB  2.7 MB/s  25m34spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  42 MB/4.1 GB  2.7 MB/s  25m34spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  43 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  43 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  43 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  43 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  44 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  44 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  44 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  44 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  45 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  45 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  45 MB/4.1 GB  2.7 MB/s  24m59spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  45 MB/4.1 GB  2.7 MB/s  24m44spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  46 MB/4.1 GB  2.7 MB/s  24m43spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  46 MB/4.1 GB  2.7 MB/s  24m43spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  47 MB/4.1 GB  2.7 MB/s  24m43spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  48 MB/4.1 GB  2.7 MB/s  24m43spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  48 MB/4.1 GB  2.7 MB/s  24m43spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  49 MB/4.1 GB  2.7 MB/s  24m42spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  49 MB/4.1 GB  2.7 MB/s  24m42spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  49 MB/4.1 GB  2.7 MB/s  24m42spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  50 MB/4.1 GB  2.7 MB/s  24m42spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  50 MB/4.1 GB  3.0 MB/s  22m41spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  50 MB/4.1 GB  3.0 MB/s  22m41spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  50 MB/4.1 GB  3.0 MB/s  22m41spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  51 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  51 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  52 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  52 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  52 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  53 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  54 MB/4.1 GB  3.0 MB/s  22m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  54 MB/4.1 GB  3.1 MB/s  21m40spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  54 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  55 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  55 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  55 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  56 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  56 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  57 MB/4.1 GB  3.1 MB/s  21m39spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  58 MB/4.1 GB  3.1 MB/s  21m38spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  58 MB/4.1 GB  3.1 MB/s  21m38spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  59 MB/4.1 GB  3.5 MB/s  19m30spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  60 MB/4.1 GB  3.5 MB/s  19m30spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  60 MB/4.1 GB  3.5 MB/s  19m30spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  61 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  61 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   1% ▕                  ▏  61 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  62 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  62 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  62 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  62 MB/4.1 GB  3.5 MB/s  19m29spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  62 MB/4.1 GB  3.5 MB/s   19m5spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  63 MB/4.1 GB  3.5 MB/s   19m5spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  64 MB/4.1 GB  3.5 MB/s   19m5spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  65 MB/4.1 GB  3.5 MB/s   19m5spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  65 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  65 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  66 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  66 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  67 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  67 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  67 MB/4.1 GB  3.5 MB/s   19m4spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  68 MB/4.1 GB  3.8 MB/s  17m55spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  69 MB/4.1 GB  3.8 MB/s  17m55spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  69 MB/4.1 GB  3.8 MB/s  17m55spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  70 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  70 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  70 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  71 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  71 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  71 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  71 MB/4.1 GB  3.8 MB/s  17m54spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  72 MB/4.1 GB  3.9 MB/s  17m21spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  73 MB/4.1 GB  3.9 MB/s  17m21spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  73 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  74 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  74 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  74 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  75 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  75 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  76 MB/4.1 GB  3.9 MB/s  17m20spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  77 MB/4.1 GB  3.9 MB/s  17m19spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  77 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  78 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  78 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  78 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  79 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  79 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  79 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  79 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  80 MB/4.1 GB  4.2 MB/s   16m3spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  81 MB/4.1 GB  4.2 MB/s   16m2spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  81 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  82 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  82 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  82 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  83 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  83 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  84 MB/4.1 GB  4.2 MB/s  15m56spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  85 MB/4.1 GB  4.2 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  85 MB/4.1 GB  4.2 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  86 MB/4.1 GB  4.2 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  86 MB/4.1 GB  4.6 MB/s  14m36spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  87 MB/4.1 GB  4.6 MB/s  14m36spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  87 MB/4.1 GB  4.6 MB/s  14m36spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  87 MB/4.1 GB  4.6 MB/s  14m36spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  88 MB/4.1 GB  4.6 MB/s  14m36spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  88 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  89 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  89 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  90 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  90 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  90 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  92 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  92 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  92 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  93 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  93 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  93 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  94 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  94 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  94 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  95 MB/4.1 GB  4.6 MB/s  14m39spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  95 MB/4.1 GB  4.6 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  96 MB/4.1 GB  4.6 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  96 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  96 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  96 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  97 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  98 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  98 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  98 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  99 MB/4.1 GB  4.6 MB/s  14m40spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏  99 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 100 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 100 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 101 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 101 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 101 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 101 MB/4.1 GB  4.5 MB/s  14m51spulling manifest
# pulling ff82381e2bea:   2% ▕                  ▏ 102 MB/4.1 GB  4.5 MB/s  14m50spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 103 MB/4.1 GB  4.5 MB/s  14m50spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 103 MB/4.1 GB  4.5 MB/s  14m50spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 104 MB/4.1 GB  4.6 MB/s  14m36spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 104 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 105 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 105 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 105 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 105 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 105 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 106 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 106 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 107 MB/4.1 GB  4.6 MB/s  14m35spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 108 MB/4.1 GB  4.5 MB/s  14m59spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 108 MB/4.1 GB  4.5 MB/s  14m59spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 109 MB/4.1 GB  4.5 MB/s  14m59spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 109 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 110 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 110 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 110 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 111 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 111 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 112 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 113 MB/4.1 GB  4.5 MB/s  14m58spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 113 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 114 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 114 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 114 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 115 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 115 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 116 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 117 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 117 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 118 MB/4.1 GB  4.6 MB/s  14m24spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 119 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 119 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 119 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 120 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 120 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 121 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 122 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 122 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 122 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 123 MB/4.1 GB  4.6 MB/s  14m25spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 123 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 124 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 124 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 124 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 125 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 126 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 126 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 127 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 127 MB/4.1 GB  4.7 MB/s  14m15spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 127 MB/4.1 GB  4.7 MB/s  14m14spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 128 MB/4.1 GB  4.6 MB/s  14m19spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 129 MB/4.1 GB  4.6 MB/s  14m19spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 129 MB/4.1 GB  4.6 MB/s  14m19spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 130 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 130 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 131 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 131 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 132 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 132 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 133 MB/4.1 GB  4.6 MB/s  14m18spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 133 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 133 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 133 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 134 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 134 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 134 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 135 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 135 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 136 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 137 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 137 MB/4.1 GB  4.6 MB/s  14m26spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 137 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 137 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 138 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 138 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 138 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 139 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 139 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 139 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 139 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 140 MB/4.1 GB  4.6 MB/s  14m17spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 140 MB/4.1 GB  4.5 MB/s  14m42spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 141 MB/4.1 GB  4.5 MB/s  14m42spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 141 MB/4.1 GB  4.5 MB/s  14m42spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 141 MB/4.1 GB  4.5 MB/s  14m42spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 142 MB/4.1 GB  4.5 MB/s  14m42spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 142 MB/4.1 GB  4.5 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   3% ▕                  ▏ 143 MB/4.1 GB  4.5 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 143 MB/4.1 GB  4.5 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 144 MB/4.1 GB  4.5 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 145 MB/4.1 GB  4.5 MB/s  14m41spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 145 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 145 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 146 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 146 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 146 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 146 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 147 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 147 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 148 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 148 MB/4.1 GB  4.6 MB/s  14m27spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 148 MB/4.1 GB  4.5 MB/s  14m33spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 149 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 149 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 150 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 151 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 151 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 151 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 152 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 152 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 152 MB/4.1 GB  4.5 MB/s  14m32spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 152 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 153 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 153 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 153 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 154 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 154 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 155 MB/4.1 GB  4.3 MB/s  15m15spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 155 MB/4.1 GB  4.3 MB/s  15m14spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 156 MB/4.1 GB  4.3 MB/s  15m14spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 156 MB/4.1 GB  4.3 MB/s  15m14spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 156 MB/4.1 GB  4.3 MB/s  15m14spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 156 MB/4.1 GB  4.2 MB/s  15m46spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 157 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 157 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 158 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 159 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 159 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 159 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 160 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 160 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 161 MB/4.1 GB  4.2 MB/s  15m45spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 161 MB/4.1 GB  4.2 MB/s  15m44spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 161 MB/4.1 GB  4.2 MB/s  15m44spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 162 MB/4.1 GB  4.2 MB/s  15m44spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 162 MB/4.1 GB  4.2 MB/s  15m44spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 162 MB/4.1 GB  4.2 MB/s  15m43spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 163 MB/4.1 GB  4.2 MB/s  15m43spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 164 MB/4.1 GB  4.2 MB/s  15m43spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 164 MB/4.1 GB  4.2 MB/s  15m43spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 164 MB/4.1 GB  4.2 MB/s  15m43spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 165 MB/4.1 GB  4.2 MB/s  15m43spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 165 MB/4.1 GB  4.1 MB/s   16m7spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 166 MB/4.1 GB  4.1 MB/s   16m7spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 166 MB/4.1 GB  4.1 MB/s   16m7spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 166 MB/4.1 GB  4.1 MB/s   16m7spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 166 MB/4.1 GB  4.1 MB/s   16m7spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 167 MB/4.1 GB  4.1 MB/s   16m6spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 168 MB/4.1 GB  4.1 MB/s   16m6spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 169 MB/4.1 GB  4.1 MB/s   16m6spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 169 MB/4.1 GB  4.1 MB/s   16m6spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 169 MB/4.1 GB  4.1 MB/s   16m6spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 170 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 170 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 170 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 171 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 171 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 171 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 172 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 173 MB/4.1 GB  4.1 MB/s  15m54spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 173 MB/4.1 GB  4.1 MB/s  15m54spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 173 MB/4.1 GB  4.1 MB/s  15m54spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 174 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 174 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 174 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 175 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 175 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 176 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 176 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 176 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 176 MB/4.1 GB  4.1 MB/s  15m55spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 177 MB/4.1 GB  4.1 MB/s  15m54spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 177 MB/4.1 GB  4.1 MB/s  15m54spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 177 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 178 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 178 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 179 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 179 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 180 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 181 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 181 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 181 MB/4.1 GB  4.1 MB/s  15m51spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 182 MB/4.1 GB  4.1 MB/s  15m50spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 182 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 182 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 183 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 184 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   4% ▕                  ▏ 184 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   5% ▕                  ▏ 185 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   5% ▕                  ▏ 186 MB/4.1 GB  4.1 MB/s  15m49spulling manifest
# pulling ff82381e2bea:   5% ▕                  ▏ 186 MB/4.1 GB  4.1 MB/s  15m48spulling manifest
# pulling ff82381e2bea:   5% ▕                  ▏ 186 MB/4.1 GB  4.1 MB/s  15m48spulling manifest
# pulling ff82381e2bea:   5% ▕                  ▏ 187 MB/4.1 GB  4.1 MB/s  15m48spulling manifest
# ...
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m30spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m30spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m30spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m30spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m30spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m30spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m29spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m29spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m29spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m29spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m29spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.6 MB/s  14m11spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m19spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m18spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m18spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m17spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m39spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m36spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m35spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m35spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.5 MB/s  14m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.4 MB/s  15m23spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m26spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m25spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m25spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  16m25spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m32spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m32spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m32spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m32spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.3 MB/s  17m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m46spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m46spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m46spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m46spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m46spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m54spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m32spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  20m31spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m58spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m58spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m58spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m58spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m58spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m57spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m57spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m57spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m57spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m57spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m45spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m44spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m14spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.1 MB/s  19m13spulling manifest
# pulling ff82381e2bea:  68% ▕████████████      ▏ 2.8 GB/4.1 GB  1.2 MB/s  18m40s

# %%
warnings.filterwarnings("ignore")

# %%
#local_llm = "mistral"
local_llm = "llama3:latest"
#local_llm = "llama3.2:1b"

# %%
# Define LLM

# Local LLM:
llm = ChatOllama(
    model=local_llm,
    temperature=0,
    base_url="http://localhost:11434"
)

# %%
query = """
    Answer the following multiple-choice question. Respond only with the according disease without any preceding number or comment:\n\n
    {multiple_choice_question}
    """

# %%
prompt_template = PromptTemplate(
    input_variables=["multiple_choice_question"],
    template=query
)

# %%
chain = prompt_template | llm

# %% [markdown]
# #### SYNC:

# %%
llm_responses_pure = []
for question in tqdm(sample_questions):
    output = chain.invoke(input={"multiple_choice_question": question})
    llm_responses_pure.append(output)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:53<00:00,  1.88it/s]

# %% [markdown]
# #### ASYNC:

# %%
async def get_responses_batch(sample_questions):
    # Prepare the list of inputs for the chain
    batch_inputs = [{"multiple_choice_question": q} for q in sample_questions]
    
    # control concurrency
    config = RunnableConfig(max_concurrency=200) 
    
    llm_responses = await chain.abatch(batch_inputs, config=config)
    
    return llm_responses

async def get_responses(sample_questions):
    print("Starting concurrent LLM requests using batching...")
    llm_responses_pure = await get_responses_batch(sample_questions)
    print("All LLM responses received.")
    print(f"Received {len(llm_responses_pure)} responses.")
    return llm_responses_pure

llm_responses_pure = await get_responses(sample_questions)
# Out:
# Starting concurrent LLM requests using batching...
# All LLM responses received.
# Received 100 responses.

# %%
len(llm_responses_pure)
# Out:
# 100

# %%
llm_pure_response_texts = [response.content for response in llm_responses_pure]

# %%
llm_pure_response_texts[:10]
# Out:
# ['Flu',
#  'Vasculitis',
#  'Rosacea',
#  'Multiple myeloma',
#  'Psoriasis',
#  'Deep Vein Thrombosis (DVT)',
#  'Malaria',
#  'Essential tremor',
#  'Myocarditis',
#  'Acid Reflux Disease']

# %% [markdown]
# ### Eval score

# %%
y_true = sample_answers

# %%
len(y_true), len(llm_pure_response_texts)
# Out:
# (100, 100)

# %%
accuracy_score(y_true, llm_pure_response_texts)
# Out:
# 0.74

# %%
# DB: MedQuad q + full answers

# Without RAG
# local mistral: acc 0.6 + more talkative
# local llama3: acc 0.74

# WITH RAG
# local llama3: acc 0.94

# %%
# DB: MedQuad q + full answers

# Pure local LLM
# llama3: acc 0.74

# QureAI:
# llama3: acc 0.94

# %%
for a,b in zip(y_true, llm_pure_response_texts):
    if not a==b:
        print(a)
        print(b)
        print("")
        print("------")
        print("")
# Out:
# Toxoplasmosis
# Rosacea
#
# ------
#
# Necrotizing fasciitis
# Deep Vein Thrombosis (DVT)
#
# ------
#
# Gastritis
# Acid Reflux Disease
#
# ------
#
# Polycystic kidney disease
# Kidney Stone
#
# ------
#
# Oral leukoplakia
# Hemophiliac Lung Disease
#
# ------
#
# Essential tremor
# Huntington's disease
#
# ------
#
# Emphysema
# Myocardial Infarction
#
# ------
#
# Myoclonus
# Huntington's disease
#
# ------
#
# Meningioma
# Encephalitis
#
# ------
#
# Anxiety
# Hypercalcemia
#
# ------
#
# Cystic Fibrosis
# Lung Cancer
#
# ------
#
# Thalassemia
# Gastroesophageal Reflux Disease (GERD)
#
# ------
#
# Leishmaniasis
# Chronic rheumatic fever
#
# ------
#
# Myositis
# Guillain-Barré Syndrome
#
# ------
#
# Emphysema
# Myocardial Infarction
#
# ------
#
# Dementia
# Huntington's
#
# ------
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# ------
#
# Priapism
# Chlamydia
#
# ------
#
# Aspergillosis
# Aortic Dissection
#
# ------
#
# Frostbite
# Raynaud's disease
#
# ------
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# ------
#
# Priapism
# Chlamydia
#
# ------
#
# Muscular dystrophy
# Pneumonia
#
# ------
#
# Muscular dystrophy
# Sporotrichosis
#
# ------
#
# Scabies
# Pemphigoid
#
# ------
#
# Aspergillosis
# Aortic Dissection
#
# ------

# %% [markdown]
# ## Eval with RAG

# %%
task = "Answer the following multiple-choice question. Respond only with the according disease without any preceding number or comment: "

# %% [markdown]
# #### SYNC

# %%
index = 0
llm_responses_RAG = []
for question in tqdm(sample_questions):
    prompt = task + "\n\n" + question
    output = TestBot_for_Eval.chatbot_response(prompt)   
    llm_responses_RAG.append(output)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [17:42<00:00, 10.62s/it]

# %% [markdown]
# ### Eval score

# %%
y_true = sample_answers

# %%
len(y_true), len(llm_responses_RAG)
# Out:
# (100, 100)

# %%
y_true_lower = [y.lower() for y in y_true]
llm_responses_RAG_lower = [resp.lower() for resp in llm_responses_RAG]

# %%
accuracy_score(y_true, llm_responses_RAG)
#accuracy_score(y_true_lower, llm_responses_RAG_lower)
# Out:
# 0.87

# %%
# EVALUATION ON FULL TEST DATASET

# Local Llama3:   acc 0.66
# QureAI:         acc 0.26
    

# EVALUATION ON TEST DATASET REDUCED TO DATABASE KNOWLEDGE

# Local Llama3:   acc 0.75
# QureAI:         acc 0.91

# %%
# DB: MedQuad q + full answers


# EVALUATION ON FULL TEST DATASET

# Without RAG:
# llama model:                   acc 0.66

# With RAG:
# llama model, chunk_size ?:     acc 0.26



# EVALUATION ON TEST DATASET REDUCED TO MEDBOT-KNOWN DISEASES 

# Without RAG:
# llama model:                    acc 0.75

# With RAG:
# llama model, chunk_size 200:    acc 0.91
# llama model, chunk_size 2_000:  acc 0.94
# llama model, q + full answers:  acc 0.95

# %%
#for a,b in zip(y_true, llm_responses_RAG):
for a,b in zip(y_true_lower, llm_responses_RAG_lower):
    if not a==b:
        print(a)
        print(b)
        print("")
# Out:
# multiple sclerosis
# chronic inflammatory demyelinating polyneuropathy
#
# cystic fibrosis
# lung cancer
#
# frostbite
# raynaud's disease
#
# myoclonus
# huntington's disease
#
# lice
# psoriasis
#
# cholesteatoma
# otitis media
#
# thrombocytopenia
# kidney cancer
#
# multiple sclerosis
# chronic inflammatory demyelinating polyneuropathy
#
# pseudohypoparathyroidism
# fibromyalgia
#
# hemochromatosis
# testicular cancer
#
# thalassemia
# pneumonia
#
# kaposi sarcoma
# peripheral artery disease
#
# cystic fibrosis
# pneumonia
#
# scleroderma
# psoriasis
#
# myositis
# rheumatoid arthritis
#
# pemphigus
# psoriasis
#
# encephalitis
# multiple sclerosis
#
# hypoglycemia
# sarcoidosis
#
# tendinitis
# fibromyalgia
#
# marfan syndrome
# gastroesophageal reflux disease (gerd)
#
# marfan syndrome
# irritable bowel syndrome (ibs)
#
# autism
# epilepsy
#
# rabies
# migraine
#
# cataract
# glaucoma
#
# polycythemia vera
# lupus
#
# hemophilia
# pulmonary embolism
#
# achalasia
# esophageal cancer
#
# von willebrand disease
# thrombocytopenia
#
# muscular dystrophy
# guillain-barré syndrome
#
# emphysema
# pneumonia
#
# polycythemia vera
# lupus
#
# carcinoid syndrome
# multiple sclerosis
#
# hypothermia
# guillain-barré syndrome
#
# anemia
# thrombocytopenia
#
# kaposi sarcoma
# peripheral artery disease
#
# vasculitis
# lupus
#
# scoliosis
# spinal stenosis
#
# cataract
# glaucoma
#
# hpv
# human papillomavirus (hpv)
#
# impetigo
# staphylococcal scalded skin syndrome
#
# rabies
# migraine
#
# blastomycosis
# migraine
#
# myositis
# psoriasis
#
# croup
# pneumonia
#
# amyloidosis
# pulmonary embolism
#
# indigestion
# gastroesophageal reflux disease (gerd)
#
# delirium
# alzheimer's disease
#
# anxiety
# anxiety disorder
#
# frostbite
# raynaud's disease
#
# congenital rubella
# migraine
#
# gastritis
# gastrointestinal reflux disease (gerd)
#
# hepatic encephalopathy
# pulmonary embolism
#
# carcinoid syndrome
# multiple sclerosis
#
# neurofibromatosis
# huntington's disease
#
# hydatidiform mole
# ectopic pregnancy
#
# priapism
# prostatitis
#
# graves disease
# graves' disease
#
# anxiety
# panic disorder

# %% [markdown]
# #### ASYNC

# %%
from langchain_core.runnables import chain
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
import warnings
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.prompts.prompt import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
import csv
import os

from langchain_core.callbacks import BaseCallbackHandler
from langchain_core.messages import BaseMessage
from typing import List, Dict, Any
from langchain.memory import ChatMessageHistory

# %%
embedding_model = HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2')

# %%
################################

# Hyperparameters

# threshold for similarity computation between user query and database vectors
similarity_threshold = 0.3

# max number of retrieved chunks (could be less depending on similarity scores and threshold)
k = 3


################################

warnings.filterwarnings("ignore")


# Local:
llm = ChatOllama(
    model=local_llm,
    temperature=0,
    # other params...
)

# === NEW: TQDM CALLBACK FOR BATCH PROCESSING ===
class TQDMCallback(BaseCallbackHandler):
    """A callback handler that updates a tqdm progress bar."""
    def __init__(self, total_tasks, description="Processing LLM Requests"):
        self.progress_bar = tqdm_asyncio(total=total_tasks, desc=description)

    def on_llm_end(self, response: BaseMessage, **kwargs: Any) -> None:
        """Callback for when the LLM finishes a call."""
        self.progress_bar.update(1)

    def __del__(self):
        """Ensure the progress bar is closed when the object is deleted."""
        self.progress_bar.close()


# === ASYNCHRONOUSLY-COMPATIBLE RAG PIPELINE ===

# Load embedded chunks from Vector Database 
async def aretrieve_from_vector_db(vector_db_path):
    """
    This function splits out a retriever object from a local vector database asynchronously.
    """
    embeddings = embedding_model
    
    vectorstore = await asyncio.to_thread(
        FAISS.load_local,
        folder_path=vector_db_path,
        embeddings=embeddings,
        allow_dangerous_deserialization=True
    )
    return vectorstore



# This helper function extracts the content field from a message object. 
# It is used to simplify the extraction of text from model outputs.
def get_msg_content(msg):
    return msg.content


# This system prompt instructs the model to reformulate the user’s question into a standalone question, 
# ensuring it can be understood without referencing the chat history.
contextualize_system_prompt = (
"""Given a chat history and the latest user question \
which might reference context in the chat history, formulate a standalone question which can be understood \
without the chat history. Do NOT answer the question, just reformulate it if needed and otherwise return it as is."""
)


contextualize_prompt = ChatPromptTemplate.from_messages([
    ("system", contextualize_system_prompt),
    ("placeholder", "{chat_history}"),
    ("human", "{input}"),
])


contextualize_chain = (
    contextualize_prompt
    | llm
    | get_msg_content
)


qa_system_prompt = (
    "You are an assistant for any medical concerns. Answer the user's questions or queries based on the below context. " 
    "If the context doesn't contain any relevant information to the question or if the context is empty, "
    "do NOT make something up and just say 'Sorry, I don't know. Can you rephrase your concern?':"
    "\n\n"
    "###"
    "{context}"
    "###"
)


qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", qa_system_prompt),
        ("placeholder", "{chat_history}"),
        ("human", "{input}"),
    ]
)


qa_chain = (
    qa_prompt
    | llm
    | get_msg_content
)


# Define the overall chain the uses both the retrieved documents and the chat history to answer the question
# === THE MAIN CHAIN IS NOW ASYNCHRONOUS ===
@chain
async def history_aware_qa(input):
    # Rephrase the question if needed
    if input.get('chat_history'):
        #question = await contextualize_chain.ainvoke(input)   # with chat memory
        question = input['input']                       # without chat memory
    else:  
        question = input['input']
    

    # Return docs and relevance scores in the range [0, 1]. 0 is dissimilar, 1 is most similar.
    # could be empty, depending on the threshold
    similarity_results = await vectorstore.asimilarity_search_with_relevance_scores(question, k=k, score_threshold=similarity_threshold)
    if similarity_results:
        context, scores = zip(*similarity_results)
    else:   # no chunks similar enough
        context = ()

    retrieval_successful = bool(context)
   
    
    # Get the final answer
    final_response = await qa_chain.ainvoke({
        **input,
        "context": context
    })

    return (final_response, retrieval_successful)



chat_history_store = {}
def get_chat_history_for_session(session_id: str):
    if session_id not in chat_history_store:
        chat_history_store[session_id] = ChatMessageHistory()
    return chat_history_store[session_id]

qa_with_history_async = RunnableWithMessageHistory(
    history_aware_qa,
    get_chat_history_for_session,
    input_messages_key="input",
    history_messages_key="chat_history",
)

# === THE MAIN EXECUTION FUNCTION ===
async def async_chatbot_response(prompts):

    print("Loading vector database...")
    global vectorstore


    db_name = "vector_databases/vector_db_med_quad_answers"
    #db_name = "vector_databases/vector_db_med_quad_answers_full"
    #db_name = "vector_databases/vector_db_med_quad_answers_chunk_size_500"
    #db_name = "vector_databases/vector_db_med_quad_answers_chunk_size_2000"
    
    vectorstore = await aretrieve_from_vector_db(db_name)
    print(f"Vector database {db_name} loaded.")

   
    print("Starting batch processing with a progress bar...")
    
    config = RunnableConfig(
        max_concurrency=200, 
        callbacks=[TQDMCallback(total_tasks=len(prompts))],
        configurable={"session_id": "dummy_session_id"} 
    )
    
    batch_inputs = [{
        "input": q, 
        "chat_history": [],
        "configurable": {"session_id": f"session_{i}"}
    } for i, q in enumerate(prompts)]
    
    results_with_status = await qa_with_history_async.abatch(batch_inputs, config=config)

    # === CRITICAL CHANGE: Aggregate the results after the batch is complete ===
    responses = [response for response, status in results_with_status]
    failed_retrievals = [status for response, status in results_with_status if not status]
    
    num_responses_without_retrievals = len(failed_retrievals)

    print("\nBatch processing complete.")
    print(f"Total responses without retrieval: {num_responses_without_retrievals}\n")
    
    
    return responses

# %%
prompts = [task + "\n\n" + question for question in sample_questions]

# %%
llm_responses_RAG = await async_chatbot_response(prompts)
# Out:
# Loading vector database...
# Vector database vector_databases/vector_db_med_quad_answers loaded.
# Starting batch processing with a progress bar...
# Processing LLM Requests: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [01:30<00:00,  1.11it/s]
# Batch processing complete.
# Total responses without retrieval: 0

# %% [markdown]
# ### Eval score

# %%
y_true = sample_answers

# %%
len(y_true), len(llm_responses_RAG)
# Out:
# (100, 100)

# %%
accuracy_score(y_true, llm_responses_RAG)
# Out:
# 0.71

# %%
llm_responses_RAG.count("Sorry, I don't know. Can you rephrase your concern?")
# Out:
# 232

# %%
for a,b in zip(y_true, llm_responses_RAG):
    if not a==b:
        print(a)
        print(b)
        print("")
# Out:
# Turner syndrome
# Hernia
#
# Turner syndrome
# Hernia
#
# Turner syndrome
# Femoral Hernia
#
# Congenital rubella
# Benign paroxysmal positional vertical (BPPV)
#
# Congenital rubella
# BPPV
#
# Congenital rubella
# Benign paroxysmal positional vertical (BPPV)
#
# Congenital rubella
# Benign paroxysmal positional vertical (BPPV)
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Acute Coronary Syndrome
#
# Emphysema
# Myocardial Infarction
#
# Cholesteatoma
# Otitis Media
#
# Obesity
# Sinus bradycardia
#
# Obesity
# Sinus bradycardia
#
# Obesity
# Sinus bradycardia
#
# Pericarditis
# Myocardial Infarction
#
# Lice
# Scabies
#
# Lice
# Scabies
#
# Oral leukoplakia
# Hemophiliac Lung Disease
#
# Priapism
# Chlamydia
#
# Priapism
# Urinary Tract Infection (UTI)
#
# Polycystic kidney disease
# Kidney Stone
#
# Polycystic kidney disease
# Kidney Stone
#
# Amyloidosis
# Anxiety
#
# Amyloidosis
# Pulmonary Embolism
#
# Scleroderma
# Eczema
#
# Lymphoma
# Syphilis
#
# Lymphoma
# Syphilis
#
# Hepatic encephalopathy
# Hepatic Encephalopathy
#
# Leishmaniasis
# Chronic rheumatic fever
#
# Leishmaniasis
# Chronic rheumatic fever
#
# Leishmaniasis
# Chronic rheumatic fever
#
# Scurvy
# Toxic multinodular goiter
#
# Scurvy
# Toxic multinodular goiter
#
# Scurvy
# Melanoma
#
# Scurvy
# Toxic multinodular goiter
#
# Chancroid
# Folate deficiency
#
# Chancroid
# Folate deficiency
#
# Chancroid
# Folate deficiency
#
# Chancroid
# Folate deficiency
#
# Autism
# Spinocerebellar ataxia
#
# Autism
# Spinocerebellar ataxia
#
# Autism
# Epilepsy
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Hemophilia
# Pulmonary Embolism
#
# Hemophilia
# Pulmonary Embolism
#
# Hemophilia
# Pulmonary Embolism
#
# Thrombocytopenia
# Spherocytosis
#
# Thrombocytopenia
# Spherocytosis
#
# Thrombocytopenia
# Spherocytosis
#
# Thrombocytopenia
# Spherocytosis
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# Meningioma
# Lyme disease
#
# Sarcoidosis
# Pneumonia
#
# Aspergillosis
# Aortic Dissection
#
# Aspergillosis
# Aortic Dissection
#
# Aspergillosis
# Aortic Dissection
#
# Tuberculosis
# Pneumonia
#
# Croup
# Pneumonia
#
# Croup
# Pneumonia
#
# Croup
# Pneumonia
#
# Tendinitis
# Osteoarthritis
#
# Tendinitis
# Fibromyalgia
#
# Hypothermia
# Encephalitis
#
# Hypothermia
# Encephalitis
#
# Hypothermia
# Encephalitis
#
# Hypothermia
# Encephalitis
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Marfan syndrome
# Gastroesophageal Reflux Disease (GERD)
#
# Marfan syndrome
# Gastroesophageal reflux disease (GERD)
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Endocarditis
# Myocardial Infarction
#
# Scabies
# Atopic dermatitis
#
# Down syndrome
# Common Cold
#
# Down syndrome
# Common Cold
#
# Down syndrome
# Common Cold
#
# Down syndrome
# Common Cold
#
# Thalassemia
# Empyema
#
# Thalassemia
# Empyema
#
# Thalassemia
# Empyema
#
# Carcinoid syndrome
# Histoplasmosis
#
# Carcinoid syndrome
# Histoplasmosis
#
# Carcinoid syndrome
# Vitamin D deficiency
#
# Toxoplasmosis
# Vitamin A deficiency
#
# Toxoplasmosis
# Vitamin A deficiency
#
# Toxoplasmosis
# Vitamin A deficiency
#
# Delirium
# Depression
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Mastitis
#
# Necrotizing fasciitis
# Deep vein thrombosis
#
# Necrotizing fasciitis
# Deep vein thrombosis
#
# Necrotizing fasciitis
# Deep vein thrombosis
#
# Necrotizing fasciitis
# Deep vein thrombosis
#
# Asperger syndrome
# Bipolar disorder
#
# Asperger syndrome
# Bipolar Disorder
#
# Kaposi sarcoma
# Pulmonary Embolism
#
# Turner syndrome
# Hemolytic anemia
#
# Turner syndrome
# Femoral Aneurysm
#
# Turner syndrome
# Hemolytic anemia
#
# Turner syndrome
# Hemolytic anemia
#
# Glaucoma
# Retinal detachment
#
# Congenital rubella
# Wilson disease
#
# Congenital rubella
# Wilson disease
#
# Congenital rubella
# Wilson disease
#
# Congenital rubella
# Wilson disease
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Pneumonia
#
# Emphysema
# Pneumonia
#
# Cholesteatoma
# Otitis externa
#
# Indigestion
# Gallstones
#
# Pericarditis
# Myocardial Infarction
#
# Oral leukoplakia
# Toxoplasmosis
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Toxoplasmosis
#
# Priapism
# Chlamydia
#
# Polycystic kidney disease
# Kidney cancer
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Lymphedema
# Deep Vein Thrombosis (DVT)
#
# Hepatic encephalopathy
# Hepatic Encephalopathy
#
# Hepatic encephalopathy
# Hepatic Encephalopathy
#
# Hepatic encephalopathy
# Hepatic Encephalopathy
#
# Scurvy
# Acromegaly
#
# Scurvy
# Acromegaly
#
# Scurvy
# Acromegaly
#
# Scurvy
# Acromegaly
#
# Narcolepsy
# Sleep apnea
#
# Anxiety
# Glucocorticoid deficiency
#
# Anxiety
# Glucocorticoid deficiency
#
# Anxiety
# Glucocorticoid deficiency
#
# Anxiety
# Glucocorticoid deficiency
#
# Chancroid
# Aicardi-Goutières syndrome
#
# Chancroid
# Cerebral palsy
#
# Chancroid
# Cerebral palsy
#
# Hydrocephalus
# Meningitis
#
# Hydrocephalus
# Meningitis
#
# Cystic Fibrosis
# Panic attack
#
# Cystic Fibrosis
# Panic attack
#
# Cystic Fibrosis
# Panic attack
#
# Autism
# Fragile X syndrome
#
# Autism
# Fragile X syndrome
#
# Cat scratch disease
# Hidradenitis Suppurativa
#
# Cat scratch disease
# Lymphangitis
#
# Cat scratch disease
# Hidradenitis Suppurativa
#
# Cat scratch disease
# Lymphangitis
#
# Hemophilia
# Orbital cellulitis
#
# Pseudohypoparathyroidism
# Spondyloarthritis
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# Muscular dystrophy
# Sorry, I don't know. Can you rephrase your concern?
#
# Muscular dystrophy
# Pneumonia
#
# Muscular dystrophy
# Pneumonia
#
# Meningioma
# Encephalitis
#
# Meningioma
# Encephalitis
#
# Sarcoidosis
# Pneumonia
#
# Aspergillosis
# Aortic Dissection
#
# Aspergillosis
# Aortic Dissection
#
# Crohn disease
# Gastroenteritis
#
# Tuberculosis
# Pneumonia
#
# Croup
# Pneumonia
#
# Lyme disease
# Viral hepatitis
#
# Lyme disease
# Viral hepatitis
#
# Impetigo
# Granuloma inguinale
#
# Impetigo
# Granuloma inguinale
#
# Hypothermia
# Tetanus
#
# Hypothermia
# Cranial nerve palsy
#
# Hypothermia
# Cranial nerve palsy
#
# Hypothermia
# Tetanus
#
# Marfan syndrome
# Gastroesophageal reflux disease (GERD)
#
# Marfan syndrome
# Gastroesophageal reflux disease (GERD)
#
# Marfan syndrome
# Gastroesophageal reflux disease (GERD)
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Endocarditis
# Myocardial Infarction
#
# Endocarditis
# Myocardial Infarction
#
# Reactive arthritis
# Osteoarthritis
#
# Frostbite
# Raynaud's disease
#
# Essential tremor
# Huntington's disease
#
# Essential tremor
# Huntington's disease
#
# Down syndrome
# Encephalitis
#
# Down syndrome
# Encephalitis
#
# Down syndrome
# Encephalitis
#
# Down syndrome
# Encephalitis
#
# Thalassemia
# Gastroesophageal Reflux Disease
#
# Thalassemia
# Gastroesophageal Reflux Disease (GERD)
#
# Thalassemia
# Gastroesophageal Reflux Disease (GERD)
#
# Carcinoid syndrome
# Myasthenia gravis
#
# Carcinoid syndrome
# Myasthenia gravis
#
# Toxoplasmosis
# Rosacea
#
# Toxoplasmosis
# Rosacea
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Necrotizing fasciitis
# Hormone disorder
#
# Necrotizing fasciitis
# Hormone disorder
#
# Necrotizing fasciitis
# Achalasia
#
# Turner syndrome
# Hemophilia
#
# Turner syndrome
# Hemophilia
#
# Turner syndrome
# Hemophilia
#
# Turner syndrome
# Hemophilia
#
# Glaucoma
# Lymphogranuloma venereum
#
# Congenital rubella
# Torticollis
#
# Congenital rubella
# Torticollis
#
# Congenital rubella
# Torticollis
#
# Congenital rubella
# Torticollis
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Acute Coronary Syndrome
#
# Hashimoto thyroiditis
# Psoriasis
#
# Cholesteatoma
# Middle Ear Infection (Otitis Media)
#
# Cholesteatoma
# Middle Ear Infection (Otitis Media)
#
# Indigestion
# Gastroesophageal Reflux Disease (GERD)
#
# Myoclonus
# Huntington's disease
#
# Lice
# Chagas disease
#
# Lice
# Pediculosis (Lice)
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Priapism
# Chlamydia
#
# Priapism
# Chlamydia
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Amyloidosis
# Congestive Heart Failure
#
# Scleroderma
# Eczema
#
# Lymphoma
# Thyroiditis
#
# Hepatic encephalopathy
# Hepatic Encephalopathy
#
# Hepatic encephalopathy
# Hepatic Encephalopathy
#
# Leishmaniasis
# Wilson disease
#
# Leishmaniasis
# Wilson disease
#
# Leishmaniasis
# Wilson disease
#
# Leishmaniasis
# Wilson disease
#
# Scurvy
# Fibromatosis
#
# Scurvy
# Osteochondromatosis
#
# Scurvy
# Osteochondroma
#
# Anxiety
# Hypercalcemia
#
# Anxiety
# Hypercalcemia
#
# Leukemia
# Cysticercosis
#
# Chancroid
# Trigeminal Neuralgia
#
# Hydrocephalus
# Subarachnoid Hemorrhage
#
# Cystic Fibrosis
# Cryptococcosis
#
# Cystic Fibrosis
# Cryptococcosis
#
# Cystic Fibrosis
# Cryptococcosis
#
# Cystic Fibrosis
# Cryptococcosis
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Rabies
# Pulmonary eosinophilia
#
# Hemophilia
# Cytomegalovirus infection
#
# Hemophilia
# Cytomegalovirus infection
#
# Hemophilia
# Cytomegalovirus infection
#
# Hemophilia
# Cytomegalovirus infection
#
# Gastroparesis
# Acute Gastrointestinal Obstruction
#
# Thrombocytopenia
# Sepsis
#
# Thrombocytopenia
# Thrombotic Microangiopathy
#
# Thrombocytopenia
# Thrombotic Microangiopathy
#
# Pseudohypoparathyroidism
# Behcet disease
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# Pseudohypoparathyroidism
# Behcet disease
#
# Pseudohypoparathyroidism
# Behcet disease
#
# Muscular dystrophy
# Guillain-Barré Syndrome
#
# Muscular dystrophy
# Guillain-Barré Syndrome
#
# Meningioma
# Subarachnoid Hemorrhage
#
# Sarcoidosis
# Pneumonia
#
# Aspergillosis
# Ectopic pregnancy
#
# Aspergillosis
# Sorry, I don't know. Can you rephrase your concern?
#
# Aspergillosis
# Sorry, I don't know. Can you rephrase your concern?
#
# Crohn disease
# Gastroenteritis
#
# Tuberculosis
# Pneumonia
#
# Dementia
# Huntington's Disease
#
# Dementia
# Huntington's Disease
#
# Dementia
# Huntington's Disease
#
# Dementia
# Huntington's Disease
#
# Cataract
# Vitamin A deficiency
#
# Cataract
# Vitamin A deficiency
#
# Cataract
# Vitamin A deficiency
#
# Myocarditis
# Pneumonia
#
# Croup
# Pneumonia
#
# Croup
# Pneumonia
#
# Lyme disease
# Rubeola (Measles)
#
# Hypothermia
# Tetanus
#
# Hypothermia
# Tetanus
#
# Hypothermia
# Tetanus
#
# Hypothermia
# Tetanus
#
# Marfan syndrome
# Gastroesophageal reflux disease (GERD)
#
# Marfan syndrome
# Gastroesophageal reflux disease (GERD)
#
# Marfan syndrome
# Gastroesophageal Reflux Disease (GERD)
#
# Marfan syndrome
# Gastroesophageal Reflux Disease (GERD)
#
# Endocarditis
# Myocardial Infarction
#
# Scabies
# Pemphigoid
#
# Scabies
# Pemphigoid
#
# Scabies
# Pemphigoid
#
# Scabies
# Pemphigoid
#
# Frostbite
# Raynaud's disease
#
# Frostbite
# Raynaud's disease
#
# Frostbite
# Raynaud's disease
#
# Essential tremor
# Huntington's disease
#
# Down syndrome
# Toxoplasmosis
#
# Down syndrome
# Encephalitis
#
# Down syndrome
# Encephalitis
#
# Down syndrome
# Encephalitis
#
# Graves disease
# Hyperthyroidism
#
# Thalassemia
# Pneumonia
#
# Thalassemia
# Pneumonia
#
# Thalassemia
# Pneumonia
#
# Thalassemia
# Pneumonia
#
# Toxoplasmosis
# Tuberous sclerosis
#
# Toxoplasmosis
# Tuberous sclerosis
#
# Toxoplasmosis
# Tuberous sclerosis
#
# Toxoplasmosis
# Tuberous sclerosis
#
# Gastritis
# Acid Reflux Disease
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Necrotizing fasciitis
# Marfan syndrome
#
# Necrotizing fasciitis
# Polymyositis
#
# Necrotizing fasciitis
# Marfan syndrome
#
# Glaucoma
# Uveitis
#
# Congenital rubella
# Meningitis
#
# Congenital rubella
# Meningitis
#
# Congenital rubella
# Meningitis
#
# Congenital rubella
# Meningitis
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Acute Coronary Syndrome
#
# Emphysema
# Myocardial Infarction
#
# Emphysema
# Myocardial Infarction
#
# Indigestion
# Gastroesophageal Reflux Disease (GERD)
#
# Lice
# Scabies
#
# Lice
# Scabies
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Oral leukoplakia
# Behçet's disease
#
# Priapism
# Chlamydia
#
# Myositis
# Guillain-Barré Syndrome
#
# Myositis
# Guillain-Barré Syndrome
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Polycystic kidney disease
# Renal cell carcinoma
#
# Amyloidosis
# Pneumonia
#
# Amyloidosis
# Pneumonia
#
# Amyloidosis
# Pneumonia
#
# Hirschsprung disease
# Hemophilia
#
# Leishmaniasis
# Uterine cancer
#
# Leishmaniasis
# Fibromyalgia
#
# Scurvy
# Ovarian Cancer
#
# Scurvy
# Ovarian Cancer
#
# Scurvy
# Ovarian Cancer
#
# Scurvy
# Ovarian Cancer
#
# Anxiety
# Panic Disorder
#
# Chancroid
# Fibromyalgia
#
# Chancroid
# Fibromyalgia
#
# Chancroid
# Fibromyalgia
#
# Chancroid
# Fibromyalgia
#
# Hydrocephalus
# Subarachnoid Hemorrhage
#
# Cystic Fibrosis
# Leukemia
#
# Cystic Fibrosis
# Leukemia
#
# Cystic Fibrosis
# Leukemia
#
# Cystic Fibrosis
# Leukemia
#
# Wilson disease
# Sleep apnea
#
# Wilson disease
# Sleep apnea
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Cat scratch disease
# Lymphedema
#
# Hemophilia
# Anemia of chronic disease
#
# Hemophilia
# Anemia of chronic disease
#
# Hemophilia
# Anemia of chronic disease
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# Pseudohypoparathyroidism
# Osteoarthritis
#
# Muscular dystrophy
# Sporotrichosis
#
# Muscular dystrophy
# Sporotrichosis
#
# Muscular dystrophy
# Sporotrichosis
#
# Muscular dystrophy
# Sporotrichosis
#
# Meningioma
# Lymphogranuloma venereum
#
# Meningioma
# Lymphogranuloma venereum
#
# Meningioma
# Lymphogranuloma venereum
#
# Meningioma
# Lyme disease
#
# Sarcoidosis
# Pulmonary Embolism
#
# Aspergillosis
# Primary thrombocythemia
#
# Aspergillosis
# Primary thrombocythemia
#
# Aspergillosis
# Primary thrombocythemia
#
# Aspergillosis
# Primary thrombocythemia
#
# Tuberculosis
# Pneumonia
#
# Dementia
# Huntington's disease
#
# Dementia
# Huntington's disease
#
# Dementia
# Huntington's disease
#
# Dementia
# Huntington's disease
#
# Cataract
# Uveitis
#
# Croup
# Pneumonia
#
# Croup
# Pneumonia
#
# Croup
# Pneumonia
#
# Tendinitis
# Osteoarthritis
#
# Impetigo
# Toxoplasmosis
#
# Hypothermia
# Neonatal withdrawal syndrome
#
# Hypothermia
# Neonatal withdrawal syndrome
#
# Hypothermia
# Neonatal withdrawal syndrome
#
# Hypothermia
# Neonatal withdrawal syndrome
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Marfan syndrome
# Sorry, I don't know. Can you rephrase your concern?
#
# Endocarditis
# Myocardial Infarction
#
# Scabies
# Pemphigoid
#
# Scabies
# Pemphigoid
#
# Scabies
# Pregnancy-induced hypertension (Preeclampsia)
#
# Scabies
# Pemphigoid
#
# Frostbite
# Anemia due to malignancy
#
# Frostbite
# Polycythemia Vera
#
# Frostbite
# Polymyositis
#
# Frostbite
# Anemia due to malignancy
#
# Essential tremor
# Huntington's disease
#
# Thalassemia
# Pleurisy
#
# Thalassemia
# Pleurisy
#
# Thalassemia
# Pleurisy
#
# Thalassemia
# Pneumonia
#
# Scoliosis
# Herniated Disc
#
# Scoliosis
# Herniated Disc
#
# Epilepsy
# Neurofibromatosis type 1 (NF1)
#
# Epilepsy
# Neurofibromatosis type 1 (NF1)
#
# Epilepsy
# Neurofibromatosis type 1 (NF1)
#
# Epilepsy
# Neurofibromatosis Type 1 (NF1)
#
# Gastritis
# Acute Pancreatitis
#
# Delirium
# Schizophrenia
#
# Delirium
# Schizophrenia
#
# Delirium
# Schizophrenia
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Mastectomy
# Breast Cancer
#
# Necrotizing fasciitis
# Deep Vein Thrombosis (DVT)
